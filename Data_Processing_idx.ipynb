# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

from datetime import datetime
from sklearn.preprocessing import MultiLabelBinarizer
import geopandas as gpd
from shapely.geometry import Point

import os

# %%
pd.set_option('display.max_rows', None)

sold01 = pd.read_csv('/content/CRMLSSold202412.csv')
sold02 = pd.read_csv('/content/CRMLSSold202501_filled.csv')
sold03 = pd.read_csv('/content/CRMLSSold202502.csv')
sold04 = pd.read_csv('/content/CRMLSSold202503.csv')
sold05 = pd.read_csv('/content/CRMLSSold202504.csv')
sold06 = pd.read_csv('/content/CRMLSSold202505.csv')

# %% [markdown]
# #Research Goal
# To build a robust, user-focused machine learning model that accurately predicts the close price of any single-family residential property in California using only features available to consumers—enabling integration into a web application for real-time property value estimation.
#
# ## Data Requirment
# 1. Do not include **ListPrice** or any other features that would not be available for homes that are not currently for sale.
#
# 2. Drop the **Latfilled** and **Lonfilled** features
#
# 3. Include features that are available to the end user who is curious about the estimated close price.
#
# 4. Observation with **PropertyType** with Residential and **PropertySubType** with SingleFamilyResidence on constructing model

# %% [markdown]
# ## 1.Data Processing

# %%
print(sold01.shape)
print(sold02.shape)
print(sold03.shape)
print(sold04.shape)
print(sold05.shape)
print(sold06.shape)
# Out:
# (20241, 78)
# (18738, 80)
# (18702, 78)
# (21445, 78)
# (23262, 78)
# (23154, 78)

# %%
sold = [sold01, sold02, sold03, sold04, sold05, sold06]

for i in range(len(sold)):
  for j in range(len(sold)):
    if i != j:
      print(set(sold[i].columns)-set(sold[j].columns))
# Out:
# set()
# set()
# set()
# set()
# set()
# {'lonfilled', 'latfilled'}
# {'lonfilled', 'latfilled'}
# {'lonfilled', 'latfilled'}
# {'lonfilled', 'latfilled'}
# {'lonfilled', 'latfilled'}
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()

# %% [markdown]
# We can observe that other datasets have the same features, except the sold02 dataset is different with others involving the features of **lonfilled** and **latfilled**. Let's explore the columns for feature selection that aligns to our goal.

# %%
sold01.head()
# Out:
#    BuyerAgentAOR   ListAgentAOR              Flooring ViewYN WaterfrontYN  \
# 0       Glendale       Glendale                   NaN    NaN          NaN
# 1  InlandValleys  InlandValleys                   NaN   True          NaN
# 2    PacificWest    PacificWest                   NaN   True          NaN
# 3    Mlslistings    Mlslistings  Carpet,Laminate,Tile  False          NaN
# 4     LakeCounty     LakeCounty                   NaN   True          NaN
#
#   BasementYN PoolPrivateYN  OriginalListPrice  ListingKey  \
# 0        NaN           NaN          3350000.0   552665323
# 1        NaN           NaN           125000.0   551977092
# 2        NaN           NaN           300000.0   551927931
# 3        NaN           NaN           800000.0   544420694
# 4        NaN           NaN            21500.0   516603298
#
#                     ListAgentEmail  ... LotSizeDimensions  LotSizeArea  \
# 0        Listings@LockerRealty.com  ...               NaN      88445.0
# 1  Patriciapandeyrealtor@gmail.com  ...               NaN       9148.0
# 2          joshuacho1004@gmail.com  ...               NaN    6969600.0
# 3       assistant@danmoskowitz.com  ...               NaN       6418.0
# 4                   jan@zapcom.net  ...               NaN       4559.0
#
#   MainLevelBedrooms NewConstructionYN  GarageSpaces  HighSchoolDistrict  \
# 0               NaN             False           0.0                 NaN
# 1               NaN             False           NaN                 NaN
# 2               NaN             False           NaN                 NaN
# 3               NaN             False           0.0               Other
# 4               NaN             False           NaN                 NaN
#
#   PostalCode AssociationFee  LotSizeSquareFeet  MiddleOrJuniorSchoolDistrict
# 0      91331            NaN            88445.0                           NaN
# 1      92530            0.0             9148.0                           NaN
# 2      92356            0.0          6969600.0                           NaN
# 3      95122            NaN             6418.0                           NaN
# 4      95464            0.0             4559.0                           NaN
#
# [5 rows x 78 columns]

# %%
sorted(sold01.columns)
# Out:
# ['AboveGradeFinishedArea',
#  'AssociationFee',
#  'AssociationFeeFrequency',
#  'AttachedGarageYN',
#  'BasementYN',
#  'BathroomsTotalInteger',
#  'BedroomsTotal',
#  'BelowGradeFinishedArea',
#  'BuilderName',
#  'BuildingAreaTotal',
#  'BusinessType',
#  'BuyerAgentAOR',
#  'BuyerAgentFirstName',
#  'BuyerAgentLastName',
#  'BuyerAgentMlsId',
#  'BuyerOfficeAOR',
#  'BuyerOfficeName',
#  'City',
#  'CloseDate',
#  'ClosePrice',
#  'CoBuyerAgentFirstName',
#  'CoListAgentFirstName',
#  'CoListAgentLastName',
#  'CoListOfficeName',
#  'ContractStatusChangeDate',
#  'CountyOrParish',
#  'CoveredSpaces',
#  'DaysOnMarket',
#  'ElementarySchool',
#  'ElementarySchoolDistrict',
#  'FireplaceYN',
#  'FireplacesTotal',
#  'Flooring',
#  'GarageSpaces',
#  'HighSchool',
#  'HighSchoolDistrict',
#  'Latitude',
#  'Levels',
#  'ListAgentAOR',
#  'ListAgentEmail',
#  'ListAgentFirstName',
#  'ListAgentFullName',
#  'ListAgentLastName',
#  'ListOfficeName',
#  'ListPrice',
#  'ListingContractDate',
#  'ListingId',
#  'ListingKey',
#  'ListingKeyNumeric',
#  'LivingArea',
#  'Longitude',
#  'LotSizeAcres',
#  'LotSizeArea',
#  'LotSizeDimensions',
#  'LotSizeSquareFeet',
#  'MLSAreaMajor',
#  'MainLevelBedrooms',
#  'MiddleOrJuniorSchool',
#  'MiddleOrJuniorSchoolDistrict',
#  'MlsStatus',
#  'NewConstructionYN',
#  'OriginalListPrice',
#  'ParkingTotal',
#  'PoolPrivateYN',
#  'PostalCode',
#  'PropertySubType',
#  'PropertyType',
#  'PurchaseContractDate',
#  'StateOrProvince',
#  'Stories',
#  'StreetNumberNumeric',
#  'SubdivisionName',
#  'TaxAnnualAmount',
#  'TaxYear',
#  'UnparsedAddress',
#  'ViewYN',
#  'WaterfrontYN',
#  'YearBuilt']

# %% [markdown]
# 1.**Features should involve**:
#
# - **Property Space and Prices**: 'Living Area', 'StreetNumberNumeric', 'BathroomsTotalInteger', 'BuildingAreaTotal', 'BedroomsTotal', 'Stories', 'Levels', 'GarageSpaces', 'LotSizeSquareFeet','YearBuilt'
#
# - **Location**: 'Latitude', 'Longitude', 'UnparsedAddress', 'CountyOrParish', 'City', 'StateOrProvince', 'PostalCode'
#
# - **Facilities**: Flooring, ViewYN, WaterfrontYN, BasementYN, PoolPrivateYN, 'PropertyType' (Residential only), ‘PropertySubType’ (SingleFamilyResidence only), 'FireplacesTotal', 'AttachedGarageYN', 'ParkingTotal', 'BuilderName', 'CoveredSpaces', 'FireplaceYN', 'NewConstructionYN'
#
# - **School**: 'ElementarySchool', 'ElementarySchoolDistrict', ,'MiddleOrJuniorSchool', 'HighSchool', 'HighSchoolDistrict', 'MiddleOrJuniorSchoolDistrict'

# %% [markdown]
# **Feature exclude**:  'latfilled', 'lonfilled', 'Listprice', 'BuyerAgentAOR', 'ListAgentAOR', 'OriginalListPrice', 'ListingKey', 'ListAgentEmail' 'DaysOnMarket', 'ListOfficeName', 'BuyerOfficeName', 'CoListAgentFirstName', 'CoListAgentLastName', 'BuyerAgentMlsId', 'BuyerAgentFirstName', 'BuyerAgentLastName', 'ListingKeyNumeric', 'MLSAreaMajor', 'MlsStatus', 'BuyerOfficeAOR', 'ListingId', 'ContractStatusChangeDate', 'CoBuyerAgentFirstName', 'PurchaseContractDate', 'ListingContractDate', 'BelowGradeFinishedArea', 'BusinessType', 'MainLevelBedrooms', 'LotSizeAcres', 'LotSizeDimensions', 'LotSizeArea'

# %% [markdown]
# **Considering features**: 'CloseDate', 'AssociationFeeFrequency', 'TaxAnnualAmount', 'BuilderName', 'SubdivisionName', 'TaxYear', 'AssociationFee',

# %% [markdown]
# Let's exclude the features that not required for our research goal.

# %%
sold01 = sold01[(sold01["PropertyType"]=='Residential')&(sold01["PropertySubType"]=='SingleFamilyResidence')].drop(['ListPrice', 'BuyerAgentAOR', 'ListAgentAOR', 'OriginalListPrice', 'ListingKey', 'ListAgentEmail', 'DaysOnMarket', 'ListOfficeName', 'BuyerOfficeName', 'CoListAgentFirstName', 'CoListAgentLastName', 'BuyerAgentMlsId', 'BuyerAgentFirstName', 'BuyerAgentLastName', 'ListingKeyNumeric', 'MLSAreaMajor', 'MlsStatus', 'BuyerOfficeAOR', 'ListingId', 'ContractStatusChangeDate', 'CoBuyerAgentFirstName', 'PurchaseContractDate', 'ListingContractDate', 'BelowGradeFinishedArea', 'BusinessType', 'MainLevelBedrooms', 'LotSizeAcres', 'LotSizeDimensions', 'LotSizeArea'],axis=1, errors='ignore')
sold02 = sold02[(sold02["PropertyType"]=='Residential')&(sold02["PropertySubType"]=='SingleFamilyResidence')].drop(['latfilled', 'lonfilled','ListPrice', 'BuyerAgentAOR', 'ListAgentAOR', 'OriginalListPrice', 'ListingKey', 'ListAgentEmail', 'DaysOnMarket', 'ListOfficeName', 'BuyerOfficeName', 'CoListAgentFirstName', 'CoListAgentLastName', 'BuyerAgentMlsId', 'BuyerAgentFirstName', 'BuyerAgentLastName', 'ListingKeyNumeric', 'MLSAreaMajor', 'MlsStatus', 'BuyerOfficeAOR', 'ListingId', 'ContractStatusChangeDate', 'CoBuyerAgentFirstName', 'PurchaseContractDate', 'ListingContractDate', 'BelowGradeFinishedArea', 'BusinessType', 'MainLevelBedrooms', 'LotSizeAcres', 'LotSizeDimensions', 'LotSizeArea'], axis=1, errors='ignore')
sold03 = sold03[(sold03["PropertyType"]=='Residential')&(sold03["PropertySubType"]=='SingleFamilyResidence')].drop(['ListPrice', 'BuyerAgentAOR', 'ListAgentAOR', 'OriginalListPrice', 'ListingKey', 'ListAgentEmail', 'DaysOnMarket', 'ListOfficeName', 'BuyerOfficeName', 'CoListAgentFirstName', 'CoListAgentLastName', 'BuyerAgentMlsId', 'BuyerAgentFirstName', 'BuyerAgentLastName', 'ListingKeyNumeric', 'MLSAreaMajor', 'MlsStatus', 'BuyerOfficeAOR', 'ListingId', 'ContractStatusChangeDate', 'CoBuyerAgentFirstName', 'PurchaseContractDate', 'ListingContractDate', 'BelowGradeFinishedArea', 'BusinessType', 'MainLevelBedrooms', 'LotSizeAcres', 'LotSizeDimensions', 'LotSizeArea'], axis=1, errors='ignore')
sold04 = sold04[(sold04["PropertyType"]=='Residential')&(sold04["PropertySubType"]=='SingleFamilyResidence')].drop(['ListPrice', 'BuyerAgentAOR', 'ListAgentAOR', 'OriginalListPrice', 'ListingKey', 'ListAgentEmail', 'DaysOnMarket', 'ListOfficeName', 'BuyerOfficeName', 'CoListAgentFirstName', 'CoListAgentLastName', 'BuyerAgentMlsId', 'BuyerAgentFirstName', 'BuyerAgentLastName', 'ListingKeyNumeric', 'MLSAreaMajor', 'MlsStatus', 'BuyerOfficeAOR', 'ListingId', 'ContractStatusChangeDate', 'CoBuyerAgentFirstName', 'PurchaseContractDate', 'ListingContractDate', 'BelowGradeFinishedArea', 'BusinessType', 'MainLevelBedrooms', 'LotSizeAcres', 'LotSizeDimensions', 'LotSizeArea'], axis=1, errors='ignore')
sold05 = sold05[(sold05["PropertyType"]=='Residential')&(sold05["PropertySubType"]=='SingleFamilyResidence')].drop(['ListPrice', 'BuyerAgentAOR', 'ListAgentAOR', 'OriginalListPrice', 'ListingKey', 'ListAgentEmail', 'DaysOnMarket', 'ListOfficeName', 'BuyerOfficeName', 'CoListAgentFirstName', 'CoListAgentLastName', 'BuyerAgentMlsId', 'BuyerAgentFirstName', 'BuyerAgentLastName', 'ListingKeyNumeric', 'MLSAreaMajor', 'MlsStatus', 'BuyerOfficeAOR', 'ListingId', 'ContractStatusChangeDate', 'CoBuyerAgentFirstName', 'PurchaseContractDate', 'ListingContractDate', 'BelowGradeFinishedArea', 'BusinessType', 'MainLevelBedrooms', 'LotSizeAcres', 'LotSizeDimensions', 'LotSizeArea'], axis=1, errors='ignore')
sold06 = sold06[(sold06["PropertyType"]=='Residential')&(sold06["PropertySubType"]=='SingleFamilyResidence')].drop(['ListPrice', 'BuyerAgentAOR', 'ListAgentAOR', 'OriginalListPrice', 'ListingKey', 'ListAgentEmail', 'DaysOnMarket', 'ListOfficeName', 'BuyerOfficeName', 'CoListAgentFirstName', 'CoListAgentLastName', 'BuyerAgentMlsId', 'BuyerAgentFirstName', 'BuyerAgentLastName', 'ListingKeyNumeric', 'MLSAreaMajor', 'MlsStatus', 'BuyerOfficeAOR', 'ListingId', 'ContractStatusChangeDate', 'CoBuyerAgentFirstName', 'PurchaseContractDate', 'ListingContractDate', 'BelowGradeFinishedArea', 'BusinessType', 'MainLevelBedrooms', 'LotSizeAcres', 'LotSizeDimensions', 'LotSizeArea'], axis=1, errors='ignore')

# %% [markdown]
# Let's combine the housing price datasets of past 3 to 6 months with considering duplicates of California properties.

# %%
# combine all the datasets into one df
df= pd.concat([sold01, sold02, sold03, sold04, sold05, sold06], ignore_index=True)

row_df = df.shape[0]

print(df.shape)

#show duplicated rows. If there is, we will drop it.
print(df[df.duplicated(keep="first")])

df = df.drop_duplicates()

row_df2 = df.shape[0]

print(df.shape)
df.head()

print(row_df - row_df2)
# Out:
# (61886, 49)
#                         Flooring ViewYN WaterfrontYN BasementYN PoolPrivateYN  \
# 1527                         NaN   True          NaN        NaN         False
# 8824                         NaN   True          NaN        NaN          True
# 42783                Carpet,Tile   True          NaN        NaN         False
# 46889                        NaN   True          NaN        NaN          True
# 50916  Carpet,Laminate,Tile,Wood  False          NaN        NaN           NaN
#
#         CloseDate  ClosePrice ListAgentFirstName ListAgentLastName   Latitude  \
# 1527   2024-12-03   1499999.0            Deborah               See  32.757699
# 8824   2024-12-23   1450000.0           Brittany              Copp  32.859672
# 42783  2025-04-28    600000.0              Jewel            Cooper  33.552660
# 46889  2025-04-17    825000.0           Brittany          Olivares  36.826228
# 50916  2025-05-23   1400000.0             Cari J              Wade  37.037484
#
#        ...  Stories      HighSchool Levels  NewConstructionYN GarageSpaces  \
# 1527   ...      2.0             NaN    Two                NaN          2.0
# 8824   ...      1.0             NaN    One              False          2.0
# 42783  ...      2.0  Vista Murrieta    Two              False          2.0
# 46889  ...      2.0             NaN    Two              False          2.0
# 50916  ...      NaN           Other    NaN              False          1.0
#
#           HighSchoolDistrict  PostalCode AssociationFee  LotSizeSquareFeet  \
# 1527   La Mesa-Spring Valley       91941            0.0             8900.0
# 8824         Grossmont Union       92021            0.0           108900.0
# 42783               Murrieta       92563          105.0             2582.0
# 46889         Clovis Unified       93612            0.0            10350.0
# 50916                  Other       95018            NaN            22738.0
#
#        MiddleOrJuniorSchoolDistrict
# 1527                            NaN
# 8824                            NaN
# 42783                           NaN
# 46889                           NaN
# 50916                           NaN
#
# [5 rows x 49 columns]
# (61881, 49)
# 5

# %% [markdown]
# There are 5 duplicate rows of properties that has same value across all features. We will drop those properties and leave the one.

# %% [markdown]
# Let's check if the state listed as all California, if not, we will drop those are not.

# %%
df = df[df["StateOrProvince"]=="CA"]

row_df3 = df.shape[0]

print(df.shape)
print(row_df2-row_df3)
# Out:
# (61876, 49)
# 5

# %% [markdown]
# We only want to identify the California area housing price, and we can see that we drop 5 rows more that are not in California. (Total 5 rows dropped)

# %% [markdown]
# ## 2. Data Cleaning

# %% [markdown]
# Let's dive into location features cleaning missing values and extreme outliers.
#
# - **Location**: 'Latitude', 'Longitude', 'CountyOrParish', 'City', 'StateOrProvince', 'PostalCode'

# %%
location = ['Latitude', 'Longitude','CountyOrParish', 'City', 'StateOrProvince', 'PostalCode']
print(df[location].isna().sum())

#check if there is implicit missing values for numerical features.
print(df[location].dtypes)


df[location].head()
# Out:
# Latitude            4
# Longitude           4
# CountyOrParish      0
# City               56
# StateOrProvince     0
# PostalCode          0
# dtype: int64
# Latitude           float64
# Longitude          float64
# CountyOrParish      object
# City                object
# StateOrProvince     object
# PostalCode          object
# dtype: object
#     Latitude   Longitude CountyOrParish           City StateOrProvince  \
# 0  37.330858 -121.849610    Santa Clara       San Jose              CA
# 1  34.180411 -118.342020    Los Angeles        Burbank              CA
# 2  32.574359 -117.023836      San Diego      San Diego              CA
# 3  37.116859 -122.113773     Santa Cruz  Boulder Creek              CA
# 4  33.725080 -117.222302      Riverside        Menifee              CA
#
#   PostalCode
# 0      95122
# 1      91505
# 2      92154
# 3      95006
# 4      92586

# %% [markdown]
# We can determine that there is couple missing values of 4 **longitude** and **latitude**, 64 **addresses**, and 56 **cities**.
#
# Additionally, **latitude** and **longitude** do not have implicit missing values due to float64. We will chcek if there is implicit missing values for **city**, **county**, **state**, and **postal code**.

# %%
# Define imolicit missing values.
implicit_missing_values = [
    '',
    ' ',
    'Unknown',
    'unknown',
    'UNKNOWN',
    'N/A',
    'NA',
    'na',
    'None',
    'none',
    'NULL',
    'null',
    '--',
    '-',
    'Missing',
    'missing'
]

# Show counts for placeholder values in City
print("City placeholder counts:")

for i in location:
    col = df[i]
    implicit = col[col.isin(implicit_missing_values)].unique().tolist()
    print(f"{i} feature of values")
    print(implicit)
    print()
# Out:
# City placeholder counts:
# Latitude feature of values
# []
#
# Longitude feature of values
# []
#
# CountyOrParish feature of values
# []
#
# City feature of values
# []
#
# StateOrProvince feature of values
# []
#
# PostalCode feature of values
# []

# %% [markdown]
# There is no implicit missing values across location features.
#
# ### 1) Zipcode
# Let's check if there is invalid zipcodes first before using the zipcodes.

# %%
# make sure zipcode is string
df['PostalCode'] = df['PostalCode'].astype(str)

# Check for invalid postal codes that length should be 5 for U.S. postal codes
invalid_postal_codes = df[df['PostalCode'].str.len() != 5]
print(invalid_postal_codes)

# Print the number of rows with more than 5 characters in PostalCode
print("Number of rows with PostalCode longer than 5 digits:", invalid_postal_codes.shape[0])


df = df[df["PostalCode"].str.len()==5]


# Re-check for invalid postal codes if it excluded
invalid_postal_codes = df[df['PostalCode'].str.len() != 5]
print("Number of rows with PostalCode longer than 5 digits:", invalid_postal_codes.shape[0])
# Out:
#                               Flooring ViewYN WaterfrontYN BasementYN  \
# 11                       Laminate,Tile    NaN          NaN        NaN
# 53                    Carpet,Tile,Wood   True          NaN        NaN
# 468                             Carpet    NaN          NaN        NaN
# 821                   Carpet,Tile,Wood    NaN          NaN        NaN
# 1066                 Carpet,Vinyl,Wood    NaN          NaN        NaN
# 1144     Carpet,Concrete,Laminate,Tile    NaN          NaN        NaN
# 1231              Carpet,Laminate,Tile    NaN          NaN        NaN
# 1455                               NaN    NaN          NaN        NaN
# 1535                             Vinyl    NaN          NaN       True
# 1597                  Carpet,Tile,Wood    NaN          NaN        NaN
# 1848                            Carpet    NaN          NaN        NaN
# 2069                       Carpet,Tile    NaN          NaN        NaN
# 2207        Carpet,Laminate,Tile,Vinyl    NaN          NaN        NaN
# 2356                Laminate,Tile,Wood   True          NaN        NaN
# 2474                              Wood   True          NaN        NaN
# 2513                     Laminate,Tile    NaN          NaN        NaN
# 2590                              Wood    NaN          NaN        NaN
# 2710                              Wood   True          NaN        NaN
# 3015                       Carpet,Wood    NaN          NaN        NaN
# 3019                  Carpet,Tile,Wood    NaN          NaN        NaN
# 3058                      Carpet,Vinyl    NaN          NaN        NaN
# 3066              Carpet,Laminate,Tile    NaN          NaN        NaN
# 3074                  Carpet,Tile,Wood    NaN          NaN        NaN
# 3198                   Carpet,Laminate   True          NaN        NaN
# 3337                   Tile,Vinyl,Wood    NaN          NaN        NaN
# 3413                          Laminate    NaN          NaN        NaN
# 3496              Carpet,Laminate,Tile    NaN          NaN        NaN
# 3647                 Carpet,Stone,Wood    NaN          NaN        NaN
# 4361                   SeeRemarks,Tile   True          NaN        NaN
# 4505                               NaN    NaN          NaN        NaN
# 4835                             Stone    NaN          NaN        NaN
# 4967            Carpet,SeeRemarks,Tile    NaN          NaN        NaN
# 5094                 Carpet,Stone,Tile    NaN          NaN        NaN
# 5366                          Laminate    NaN          NaN        NaN
# 5471                       Carpet,Tile    NaN          NaN        NaN
# 5593                             Vinyl    NaN          NaN        NaN
# 5621                   Carpet,Laminate    NaN          NaN        NaN
# 5702                         Tile,Wood    NaN          NaN        NaN
# 5712             Carpet,Laminate,Vinyl    NaN          NaN        NaN
# 5734                        SeeRemarks    NaN          NaN        NaN
# 6012                          Laminate   True          NaN        NaN
# 6079                              Wood    NaN          NaN        NaN
# 6147                     Laminate,Tile    NaN          NaN        NaN
# 6171                Laminate,Tile,Wood    NaN          NaN        NaN
# 6288                     Laminate,Tile    NaN          NaN        NaN
# 6743                       Carpet,Wood    NaN          NaN        NaN
# 6926        Carpet,Laminate,Tile,Vinyl    NaN          NaN        NaN
# 7016     Carpet,Concrete,Laminate,Tile   True          NaN        NaN
# 7339                     Laminate,Tile    NaN          NaN        NaN
# 7879                     Laminate,Wood    NaN          NaN       True
# 8119                       Carpet,Wood    NaN          NaN        NaN
# 8325                  Carpet,Tile,Wood    NaN          NaN        NaN
# 8422                  Carpet,Tile,Wood    NaN          NaN        NaN
# 8612                        SeeRemarks    NaN          NaN        NaN
# 9000                 Carpet,Tile,Vinyl    NaN          NaN        NaN
# 9266                     Concrete,Tile    NaN          NaN        NaN
# 10035        Carpet,Laminate,Tile,Wood    NaN          NaN       True
# 10207                             Wood   True          NaN        NaN
# 10375                         Laminate    NaN          NaN        NaN
# 10410                             Wood   True          NaN       True
# 10419                      Carpet,Tile    NaN          NaN        NaN
# 10688                      Carpet,Wood    NaN          NaN        NaN
# 10951                             Wood   True          NaN        NaN
# 11167                             Wood    NaN          NaN        NaN
# 11315             Carpet,Laminate,Tile    NaN          NaN        NaN
# 11523                        Tile,Wood    NaN          NaN       True
# 11716                Carpet,Vinyl,Wood   True          NaN        NaN
# 12501        Carpet,Laminate,Tile,Wood   True          NaN        NaN
# 12514             SeeRemarks,Tile,Wood    NaN          NaN        NaN
# 12586           Carpet,SeeRemarks,Tile    NaN          NaN        NaN
# 12764    Laminate,SeeRemarks,Tile,Wood    NaN          NaN        NaN
# 12792    Carpet,Concrete,Laminate,Tile    NaN          NaN        NaN
# 12807                  Carpet,Laminate    NaN          NaN        NaN
# 12933                      Carpet,Tile    NaN          NaN        NaN
# 12978        Carpet,Laminate,Tile,Wood    NaN          NaN       True
# 13004                     Carpet,Vinyl    NaN          NaN        NaN
# 13406             Carpet,Laminate,Wood    NaN          NaN        NaN
# 13681                  Carpet,Laminate    NaN          NaN        NaN
# 13701                      Carpet,Tile    NaN          NaN        NaN
# 13987                        Tile,Wood    NaN          NaN        NaN
# 14278                             Wood    NaN          NaN        NaN
# 14934                              NaN    NaN          NaN        NaN
# 15029                  Carpet,Concrete    NaN          NaN        NaN
# 15282                 Carpet,Tile,Wood    NaN          NaN        NaN
# 15488                 Carpet,Tile,Wood    NaN          NaN        NaN
# 15927                 Carpet,Tile,Wood    NaN          NaN        NaN
# 15928           Carpet,Tile,Vinyl,Wood    NaN          NaN        NaN
# 16039                     Carpet,Vinyl    NaN          NaN        NaN
# 16241                     Carpet,Stone   True          NaN        NaN
# 16431       Carpet,Concrete,Tile,Vinyl    NaN          NaN        NaN
# 16859                             Wood    NaN          NaN        NaN
# 17203  Carpet,Concrete,Stone,Tile,Wood    NaN          NaN        NaN
# 17980                      Carpet,Wood   True          NaN        NaN
# 18248                             Wood    NaN          NaN        NaN
# 18983                           Carpet    NaN          NaN        NaN
# 18990                 Carpet,Tile,Wood   True          NaN        NaN
# 19177           Carpet,Stone,Tile,Wood    NaN          NaN        NaN
# 19224                      Carpet,Tile    NaN          NaN        NaN
# 19269                       Stone,Wood    NaN          NaN        NaN
# 19353                      Carpet,Tile    NaN          NaN        NaN
# 19363                        Tile,Wood   True          NaN       True
# 19387                  Tile,Vinyl,Wood    NaN          NaN        NaN
# 19987                    Laminate,Wood    NaN          NaN        NaN
# 20015                            Vinyl    NaN          NaN        NaN
# 20256                             Wood    NaN          NaN        NaN
# 20415                      Carpet,Wood    NaN          NaN        NaN
# 20431                         Laminate   True          NaN        NaN
# 20461                            Vinyl    NaN          NaN        NaN
# 20718                    Laminate,Tile    NaN          NaN        NaN
# 20735                Carpet,Tile,Vinyl    NaN          NaN        NaN
# 20980                    Laminate,Tile    NaN          NaN        NaN
# 21016                 Carpet,Tile,Wood   True          NaN        NaN
# 21051                  Carpet,Laminate    NaN          NaN        NaN
# 21635                 Carpet,Tile,Wood   True          NaN        NaN
# 21982                         Laminate    NaN          NaN        NaN
# 22121                             Wood   True          NaN       True
# 22323           Carpet,SeeRemarks,Tile    NaN          NaN        NaN
# 22704                      Carpet,Tile   True          NaN        NaN
# 22737                      Carpet,Wood    NaN          NaN        NaN
# 23139                    Laminate,Tile    NaN          NaN        NaN
# 23307                 Carpet,Tile,Wood    NaN          NaN        NaN
# 23311           Carpet,Tile,Vinyl,Wood    NaN          NaN        NaN
# 23811             Carpet,Laminate,Tile   True          NaN        NaN
# 23895                             Wood    NaN          NaN        NaN
# 23953             Carpet,Laminate,Tile    NaN          NaN        NaN
# 24220                  Carpet,Laminate    NaN          NaN        NaN
# 24632                Carpet,Vinyl,Wood    NaN          NaN        NaN
# 25020                  Carpet,Laminate    NaN          NaN        NaN
# 25599                      Carpet,Wood    NaN          NaN        NaN
# 25664                             Wood   True          NaN        NaN
# 25743                    Laminate,Tile    NaN          NaN        NaN
# 25829                 SeeRemarks,Vinyl   True          NaN        NaN
# 25980                 Carpet,Tile,Wood    NaN          NaN        NaN
# 26767           Carpet,SeeRemarks,Wood    NaN          NaN        NaN
# 26878            Carpet,Laminate,Vinyl   True          NaN        NaN
# 27179                         Laminate    NaN          NaN        NaN
# 27370                     Carpet,Vinyl   True          NaN        NaN
# 27381       Carpet,Laminate,SeeRemarks    NaN          NaN        NaN
# 27928                    Laminate,Tile    NaN          NaN        NaN
# 27953                 Carpet,Tile,Wood    NaN          NaN        NaN
# 28287                  Carpet,Laminate    NaN          NaN        NaN
# 28305                        Tile,Wood    NaN          NaN        NaN
# 28492                        Tile,Wood    NaN          NaN        NaN
# 28556                       SeeRemarks    NaN          NaN        NaN
# 28651                Carpet,Tile,Vinyl   True          NaN        NaN
# 28678                    Laminate,Tile   True          NaN        NaN
# 28902                             Wood    NaN          NaN        NaN
# 28941               Laminate,Tile,Wood    NaN          NaN        NaN
# 29304               Laminate,Tile,Wood    NaN          NaN        NaN
# 29510                 Carpet,Tile,Wood    NaN          NaN        NaN
# 29632           Carpet,SeeRemarks,Tile    NaN          NaN        NaN
# 29647                        Tile,Wood    NaN          NaN        NaN
# 29665                 Stone,Vinyl,Wood    NaN          NaN        NaN
# 29702                Carpet,Tile,Vinyl    NaN          NaN       True
# 29722                       Vinyl,Wood    NaN          NaN        NaN
# 29772                             Tile    NaN          NaN        NaN
# 29780                            Vinyl    NaN          NaN        NaN
# 29814                 Carpet,Tile,Wood    NaN          NaN        NaN
# 29986             Carpet,Laminate,Tile    NaN          NaN        NaN
# 30270                      Carpet,Wood    NaN          NaN        NaN
# 30377                           Carpet    NaN          NaN        NaN
# 30495                  Carpet,Laminate    NaN          NaN        NaN
# 30566                           Carpet    NaN          NaN        NaN
# 30766                     Carpet,Vinyl    NaN          NaN        NaN
# 30844                       Tile,Vinyl    NaN          NaN        NaN
# 30845                    Laminate,Tile    NaN          NaN        NaN
# 31042                       Tile,Vinyl    NaN          NaN        NaN
# 31386             Carpet,Concrete,Wood    NaN          NaN        NaN
# 31498                             Wood    NaN          NaN        NaN
# 31547                        Tile,Wood   True          NaN        NaN
# 31570                             Wood   True          NaN       True
# 31640                 Carpet,Tile,Wood   True          NaN        NaN
# 31677                             Wood    NaN          NaN        NaN
# 31809                         Laminate    NaN          NaN        NaN
# 31984                             Wood    NaN          NaN        NaN
# 32091                     Carpet,Vinyl   True          NaN        NaN
# 32173                             Wood    NaN          NaN        NaN
# 32591                             Wood    NaN          NaN        NaN
# 32638                 Carpet,Tile,Wood   True          NaN        NaN
# 32765             Carpet,Laminate,Tile  False          NaN        NaN
# 33377                     Carpet,Vinyl    NaN          NaN        NaN
# 33414                         Laminate    NaN          NaN        NaN
# 33617                      Carpet,Tile    NaN          NaN        NaN
# 33865             Carpet,Laminate,Tile   True          NaN        NaN
# 33937                      Carpet,Tile    NaN          NaN        NaN
# 34050                 Carpet,Tile,Wood    NaN          NaN        NaN
# 34061                            Vinyl    NaN          NaN        NaN
# 34113                Carpet,Tile,Vinyl    NaN          NaN        NaN
# 34199                 Carpet,Tile,Wood    NaN          NaN        NaN
# 35117                             Tile    NaN          NaN        NaN
# 35195                         Laminate    NaN          NaN        NaN
# 35227              Laminate,Tile,Vinyl    NaN          NaN        NaN
# 35415                              NaN    NaN          NaN        NaN
# 35508                Carpet,Tile,Vinyl    NaN          NaN        NaN
# 35901                      Carpet,Tile    NaN          NaN       True
# 35997                      Carpet,Tile    NaN          NaN        NaN
# 36551                 Carpet,Tile,Wood    NaN          NaN        NaN
# 38085                  Carpet,Laminate    NaN          NaN        NaN
# 38571                        Tile,Wood    NaN          NaN        NaN
# 38757                  Tile,Vinyl,Wood    NaN          NaN        NaN
# 38804                 Carpet,Tile,Wood    NaN          NaN        NaN
# 38891                    Laminate,Wood   True          NaN        NaN
# 39003                        Tile,Wood    NaN          NaN        NaN
# 39004                        Tile,Wood   True          NaN        NaN
# 39210                  Carpet,Laminate   True          NaN        NaN
# 39236                        Tile,Wood    NaN          NaN        NaN
# 39260                       Tile,Vinyl    NaN          NaN        NaN
# 39391       Carpet,Laminate,Tile,Vinyl    NaN          NaN        NaN
# 39534                     Carpet,Stone   True          NaN        NaN
# 39637                         Laminate    NaN          NaN        NaN
# 39670                    Laminate,Tile    NaN          NaN        NaN
# 39707                      Carpet,Wood    NaN          NaN        NaN
# 40183                             Wood   True          NaN       True
# 40346                 Carpet,Tile,Wood    NaN          NaN        NaN
# 40564               Laminate,Tile,Wood    NaN          NaN        NaN
# 40699                        Tile,Wood    NaN          NaN        NaN
# 40853                 Carpet,Tile,Wood    NaN          NaN        NaN
# 41120                 Carpet,Tile,Wood    NaN          NaN        NaN
# 41132               Laminate,Tile,Wood   True          NaN        NaN
# 41171                            Vinyl    NaN          NaN        NaN
# 41218                  Carpet,Laminate    NaN          NaN        NaN
# 41467                       Tile,Vinyl    NaN          NaN        NaN
# 41529                      Carpet,Wood    NaN          NaN        NaN
# 41823                      Carpet,Wood    NaN          NaN        NaN
# 41847                 Carpet,Tile,Wood   True          NaN        NaN
# 42007          Carpet,SeeRemarks,Vinyl    NaN          NaN        NaN
# 42016                       Stone,Wood   True          NaN        NaN
# 42069                             Wood    NaN          NaN        NaN
# 42290                        Tile,Wood    NaN          NaN        NaN
# 42473                        Tile,Wood    NaN          NaN        NaN
# 42531                             Wood    NaN          NaN        NaN
# 42577                       Tile,Vinyl    NaN          NaN        NaN
# 42795                             Tile    NaN          NaN        NaN
# 43221             Carpet,Laminate,Tile    NaN          NaN        NaN
# 43329                            Vinyl    NaN          NaN        NaN
# 43374                      Carpet,Tile    NaN          NaN        NaN
# 43893                    Laminate,Tile    NaN          NaN        NaN
# 44055                             Tile    NaN          NaN        NaN
# 44196                 Carpet,Tile,Wood   True          NaN        NaN
# 44296                            Vinyl    NaN          NaN        NaN
# 44347             Carpet,Concrete,Tile    NaN          NaN       True
# 44348                             Tile    NaN          NaN        NaN
# 44377             Carpet,Laminate,Tile    NaN          NaN        NaN
# 44674                      Carpet,Tile    NaN          NaN        NaN
# 44701                      Carpet,Tile    NaN          NaN        NaN
# 44771                  Carpet,Laminate    NaN          NaN        NaN
# 45195                              NaN    NaN          NaN        NaN
# 45351        Carpet,Laminate,Tile,Wood    NaN          NaN       True
# 45633             Carpet,Laminate,Wood    NaN          NaN        NaN
# 45842                Carpet,Tile,Vinyl    NaN          NaN        NaN
# 46222                  Tile,Vinyl,Wood    NaN          NaN        NaN
# 46340             Carpet,Laminate,Tile    NaN          NaN        NaN
# 46579                       SeeRemarks    NaN          NaN        NaN
# 46691                       Tile,Vinyl    NaN          NaN        NaN
# 46977                             Wood    NaN          NaN        NaN
# 47158        Carpet,Laminate,Tile,Wood   True          NaN        NaN
# 47193                      Carpet,Wood    NaN          NaN        NaN
# 47203                        Tile,Wood    NaN          NaN        NaN
# 47381                            Vinyl    NaN          NaN        NaN
# 47405                             Tile   True          NaN        NaN
# 47596               Laminate,Tile,Wood   True          NaN        NaN
# 47727                        Tile,Wood    NaN          NaN        NaN
# 47802                       Tile,Vinyl    NaN          NaN        NaN
# 48524                   Concrete,Vinyl    NaN          NaN        NaN
# 48680                 Carpet,Tile,Wood   True          NaN        NaN
# 49484                    Laminate,Wood    NaN          NaN        NaN
# 49612                 Carpet,Tile,Wood    NaN          NaN        NaN
# 49832                    Laminate,Tile    NaN          NaN        NaN
# 49947             Carpet,Laminate,Tile   True          NaN        NaN
# 49948                         Laminate    NaN          NaN        NaN
# 50318                  Carpet,Laminate    NaN          NaN        NaN
# 50739                  Tile,Vinyl,Wood    NaN          NaN        NaN
# 50749             Carpet,Laminate,Wood    NaN          NaN        NaN
# 50863                 Carpet,Tile,Wood    NaN          NaN        NaN
# 51330               Concrete,Tile,Wood   True          NaN        NaN
# 51544                             Wood    NaN          NaN        NaN
# 51547                 Carpet,Tile,Wood   True          NaN        NaN
# 51652                 Carpet,Tile,Wood    NaN          NaN        NaN
# 51683                 Carpet,Tile,Wood   True          NaN        NaN
# 51819                        Tile,Wood    NaN          NaN       True
# 51847                      Stone,Vinyl    NaN          NaN        NaN
# 51893                        Tile,Wood    NaN          NaN        NaN
# 51910                       Vinyl,Wood    NaN          NaN        NaN
# 51922                      Carpet,Wood    NaN          NaN        NaN
# 52014        Carpet,Laminate,Tile,Wood    NaN          NaN        NaN
# 52127                         Concrete   True          NaN        NaN
# 52140                             Wood    NaN          NaN        NaN
# 52573         Laminate,Stone,Tile,Wood    NaN          NaN        NaN
# 52655                    Laminate,Tile    NaN          NaN        NaN
# 52908                         Laminate    NaN          NaN        NaN
# 53005                    Laminate,Tile    NaN          NaN        NaN
# 53066               Laminate,Tile,Wood    NaN          NaN        NaN
# 53162           Carpet,Tile,Vinyl,Wood   True          NaN        NaN
# 53164                           Carpet    NaN          NaN        NaN
# 53280                             Wood    NaN          NaN        NaN
# 53374        Carpet,Laminate,Tile,Wood   True          NaN        NaN
# 53567               Laminate,Tile,Wood    NaN          NaN        NaN
# 53637                        Tile,Wood    NaN          NaN       True
# 53836                    Laminate,Wood    NaN          NaN        NaN
# 53861                            Vinyl    NaN          NaN        NaN
# 53950                      Carpet,Tile    NaN          NaN        NaN
# 53980                 Carpet,Tile,Wood   True          NaN        NaN
# 53993                             Wood    NaN          NaN        NaN
# 53994                            Vinyl    NaN          NaN        NaN
# 53996            Carpet,Laminate,Stone    NaN          NaN        NaN
# 54262                        Tile,Wood    NaN          NaN        NaN
# 54580                  Carpet,Laminate    NaN          NaN        NaN
# 55075             Carpet,Laminate,Tile    NaN          NaN        NaN
# 55283                        Tile,Wood   True          NaN        NaN
# 55480         Carpet,Concrete,Laminate    NaN          NaN        NaN
# 55556                    Laminate,Tile    NaN          NaN        NaN
# 55605   Carpet,Concrete,Laminate,Vinyl    NaN          NaN        NaN
# 55754                    Laminate,Tile    NaN          NaN        NaN
# 55760                       SeeRemarks    NaN          NaN        NaN
# 57055                             Wood    NaN          NaN        NaN
# 57129                      Carpet,Tile    NaN          NaN        NaN
# 57172                         Laminate   True          NaN        NaN
# 57363                    Laminate,Wood    NaN          NaN        NaN
# 57526                       Vinyl,Wood    NaN          NaN        NaN
# 57696                     Carpet,Vinyl    NaN          NaN        NaN
# 58172                         Laminate    NaN          NaN        NaN
# 58195                         Laminate    NaN          NaN        NaN
# 58505                             Wood    NaN          NaN       True
# 58724                     Carpet,Vinyl    NaN          NaN        NaN
# 59061                              NaN   True          NaN        NaN
# 59993             Carpet,Laminate,Tile    NaN          NaN        NaN
# 60022                   Laminate,Vinyl    NaN          NaN        NaN
# 60357                             Tile    NaN          NaN        NaN
# 60440                      Carpet,Tile    NaN          NaN        NaN
# 60448                    Laminate,Wood    NaN          NaN        NaN
# 60469                  Carpet,Laminate    NaN          NaN        NaN
# 60723                      Carpet,Tile    NaN          NaN        NaN
# 60984                    Laminate,Tile    NaN          NaN        NaN
# 61331                      Carpet,Tile    NaN          NaN        NaN
#
#       PoolPrivateYN   CloseDate  ClosePrice ListAgentFirstName  \
# 11            False  2024-12-30    205000.0              Chris
# 53            False  2024-12-22   2157000.0             Kristi
# 468           False  2024-12-27   1005000.0             Kellee
# 821           False  2024-12-19    925000.0            Randall
# 1066          False  2024-12-23    816000.0               Kaku
# 1144          False  2024-12-18    509000.0            Suliman
# 1231          False  2024-12-06    615000.0             Andrew
# 1455          False  2024-12-09   1560000.0              Erick
# 1535          False  2024-12-13   1350000.0             Yankun
# 1597          False  2024-12-20   1850000.0                Sam
# 1848          False  2024-12-13   1230000.0              Jason
# 2069          False  2024-12-13    995000.0             Krista
# 2207          False  2024-12-05    850000.0            Garrett
# 2356          False  2024-12-05   1450000.0            Matthew
# 2474          False  2024-12-23   1200000.0               Leif
# 2513          False  2024-12-11   1068800.0                Joe
# 2590          False  2024-12-04    739900.0             Thomas
# 2710          False  2024-12-13   2410000.0             Blaise
# 3015          False  2024-12-13   2120000.0                 Ye
# 3019          False  2024-12-12    800000.0               Lisa
# 3058          False  2024-12-09   1655000.0                 PJ
# 3066          False  2024-12-12    640000.0              Wendy
# 3074          False  2024-12-17    770000.0              Wendy
# 3198          False  2024-12-20    700000.0              Linda
# 3337          False  2024-12-13   1205000.0              Kelly
# 3413          False  2024-12-16    315000.0                 Li
# 3496          False  2024-12-12    485000.0                Lea
# 3647          False  2024-12-06   2210000.0               Dave
# 4361          False  2024-12-10   1250000.0               Ruth
# 4505          False  2024-12-03   1372000.0               Neil
# 4835          False  2024-12-13   1800000.0             Nathan
# 4967          False  2024-12-05    620000.0            Juliann
# 5094          False  2024-12-19   1981000.0            Prerana
# 5366          False  2024-12-05   1150000.0                Joe
# 5471          False  2024-12-02   1415000.0            Harshad
# 5593          False  2024-12-02   1327095.0              Preet
# 5621          False  2024-12-13    800000.0             Laurie
# 5702          False  2024-12-06   1250000.0            Soulmaz
# 5712          False  2024-12-19   1300000.0             Robert
# 5734          False  2024-12-20   1290000.0               Andy
# 6012          False  2024-12-30    750000.0             Joshua
# 6079          False  2024-12-10    770000.0             Nathan
# 6147          False  2024-12-02    785000.0              Kevin
# 6171          False  2024-12-04    850000.0               Greg
# 6288          False  2024-12-30    356000.0              Grant
# 6743          False  2024-12-04    730000.0                Rob
# 6926          False  2024-12-04   1400000.0              Xuxia
# 7016          False  2024-12-09   1074900.0               Rick
# 52127  94538-1100          150.0             4519.0
# 52140  94610-2023            NaN             4080.0
# 52573  94549-5114            NaN            52272.0
# 52655  94521-2738            NaN             5720.0
# 52908  94509-4332            NaN             7446.0
# 53005  94550-5122            NaN             8014.0
# 53066  94550-7204           57.0             8991.0
# 53162  94549-2330            NaN           161172.0
# 53164  94565-6060            NaN             9200.0
# 53280  94539-4650            NaN             9360.0
# 53374  94595-2305            NaN            27443.0
# 53567  94541-2339            NaN             5000.0
# 53637  94618-1102            NaN             5244.0
# 53836  94521-4215            NaN             7100.0
# 53861  94531-7703            NaN             4537.0
# 53950  94505-9999            NaN             7200.0
# 53980  94549-5223            NaN            14720.0
# 53993  94563-2111            NaN            11200.0
# 53994  94705-1814            NaN             3885.0
# 53996  94566-6916            NaN             7314.0
# 54262  94539-5226            NaN             5508.0
# 54580  94523-1822            NaN            10980.0
# 55075  94587-5053            NaN             6272.0
# 55283  94563-2806            NaN            23625.0
# 55480  94531-9025            NaN             7550.0
# 55556  94513-8330            NaN             5300.0
# 55605  94568-1720            NaN             9178.0
# 55754  94587-1905            NaN             6706.0
# 55760  94553-5038            NaN             6000.0
# 57055  94563-1918            NaN            12000.0
# 57129  94550-7183          109.0             9789.0
# 57172  94555-1221            NaN             3466.0
# 57363  94509-4632            NaN             6200.0
# 57526  94595-2319            NaN             7920.0
# 57696  95354-3302            NaN             8264.0
# 58172  94513-6469          165.0             5616.0
# 58195  94509-2525            NaN             5000.0
# 58505  94553-2063            NaN             7840.0
# 58724  94513-6008          153.0             6840.0
# 59061  94578-1223            NaN             5291.0
# 59993  94565-1784            NaN             7500.0
# 60022  94551-2667            NaN             5402.0
# 60357  95138-1810            NaN             7455.0
# 60440  94505-9999            NaN             8400.0
# 60448  94572-1612            NaN             5500.0
# 60469  94565-6478            NaN             6375.0
# 60723  94513-4330          446.0             5632.0
# 60984  94561-4205          160.0             7276.0
# 61331  95726-9596            NaN            11326.0
#
#        MiddleOrJuniorSchoolDistrict
# 11                              NaN
# 53                              NaN
# 468                             NaN
# 821                             NaN
# 1066                            NaN
# 1144                            NaN
# 1231                            NaN
# 1455                            NaN
# 1535                            NaN
# 1597                            NaN
# 1848                            NaN
# 2069                            NaN
# 2207                            NaN
# 2356                            NaN
# 2474                            NaN
# 2513                            NaN
# 2590                            NaN
# 2710                            NaN
# 3015                            NaN
# 3019                            NaN
# 3058                            NaN
# 3066                            NaN
# 3074                            NaN
# 3198                            NaN
# 3337                            NaN
# 3413                            NaN
# 3496                            NaN
# 3647                            NaN
# 4361                            NaN
# 4505                            NaN
# 4835                            NaN
# 4967                            NaN
# 5094                            NaN
# 5366                            NaN
# 5471                            NaN
# 5593                            NaN
# 5621                            NaN
# 5702                            NaN
# 5712                            NaN
# 5734                            NaN
# 6012                            NaN
# 6079                            NaN
# 6147                            NaN
# 6171                            NaN
# 6288                            NaN
# 6743                            NaN
# 6926                            NaN
# 7016                            NaN
# 7339                            NaN
# 7879                            NaN
# 8119                            NaN
# 8325                            NaN
# 8422                            NaN
# 8612                            NaN
# 9000                            NaN
# 9266                            NaN
# 10035                           NaN
# 10207                           NaN
# 10375                           NaN
# 10410                           NaN
# 10419                           NaN
# 10688                           NaN
# 10951                           NaN
# 11167                           NaN
# 11315                           NaN
# 11523                           NaN
# 11716                           NaN
# 12501                           NaN
# 12514                           NaN
# 12586                           NaN
# 12764                           NaN
# 12792                           NaN
# 12807                           NaN
# 12933                           NaN
# 12978                           NaN
# 13004                           NaN
# 13406                           NaN
# 13681                           NaN
# 13701                           NaN
# 13987                           NaN
# 14278                           NaN
# 14934                           NaN
# 15029                           NaN
# 15282                           NaN
# 15488                           NaN
# 15927                           NaN
# 15928                           NaN
# 16039                           NaN
# 16241                           NaN
# 16431                           NaN
# 16859                           NaN
# 17203                           NaN
# 17980                           NaN
# 18248                           NaN
# 18983                           NaN
# 18990                           NaN
# 19177                           NaN
# 19224                           NaN
# 19269                           NaN
# 19353                           NaN
# 19363                           NaN
# 19387                           NaN
# 19987                           NaN
# 20015                           NaN
# 20256                           NaN
# 20415                           NaN
# 20431                           NaN
# 20461                           NaN
# 20718                           NaN
# 20735                           NaN
# 20980                           NaN
# 21016                           NaN
# 21051                           NaN
# 21635                           NaN
# 21982                           NaN
# 22121                           NaN
# 22323                           NaN
# 22704                           NaN
# 22737                           NaN
# 23139                           NaN
# 23307                           NaN
# 23311                           NaN
# 23811                           NaN
# 23895                           NaN
# 23953                           NaN
# 24220                           NaN
# 24632                           NaN
# 25020                           NaN
# 25599                           NaN
# 25664                           NaN
# 25743                           NaN
# 25829                           NaN
# 25980                           NaN
# 26767                           NaN
# 26878                           NaN
# 27179                           NaN
# 27370                           NaN
# 27381                           NaN
# 27928                           NaN
# 27953                           NaN
# 28287                           NaN
# 28305                           NaN
# 28492                           NaN
# 28556                           NaN
# 28651                           NaN
# 28678                           NaN
# 28902                           NaN
# 28941                           NaN
# 29304                           NaN
# 29510                           NaN
# 29632                           NaN
# 29647                           NaN
# 29665                           NaN
# 29702                           NaN
# 29722                           NaN
# 29772                           NaN
# 29780                           NaN
# 29814                           NaN
# 29986                           NaN
# 30270                           NaN
# 30377                           NaN
# 30495                           NaN
# 30566                           NaN
# 30766                           NaN
# 30844                           NaN
# 30845                           NaN
# 31042                           NaN
# 31386                           NaN
# 31498                           NaN
# 31547                           NaN
# 31570                           NaN
# 31640                           NaN
# 31677                           NaN
# 31809                           NaN
# 31984                           NaN
# 32091                           NaN
# 32173                           NaN
# 32591                           NaN
# 32638                           NaN
# 32765                           NaN
# 33377                           NaN
# 33414                           NaN
# 33617                           NaN
# 33865                           NaN
# 33937                           NaN
# 34050                           NaN
# 34061                           NaN
# 34113                           NaN
# 34199                           NaN
# 35117                           NaN
# 35195                           NaN
# 35227                           NaN
# 35415                           NaN
# 35508                           NaN
# 35901                           NaN
# 35997                           NaN
# 36551                           NaN
# 38085                           NaN
# 38571                           NaN
# 38757                           NaN
# 38804                           NaN
# 38891                           NaN
# 39003                           NaN
# 39004                           NaN
# 39210                           NaN
# 39236                           NaN
# 39260                           NaN
# 39391                           NaN
# 39534                           NaN
# 39637                           NaN
# 39670                           NaN
# 39707                           NaN
# 40183                           NaN
# 40346                           NaN
# 40564                           NaN
# 40699                           NaN
# 40853                           NaN
# 41120                           NaN
# 41132                           NaN
# 41171                           NaN
# 41218                           NaN
# 41467                           NaN
# 41529                           NaN
# 41823                           NaN
# 41847                           NaN
# 42007                           NaN
# 42016                           NaN
# 42069                           NaN
# 42290                           NaN
# 42473                           NaN
# 42531                           NaN
# 42577                           NaN
# 42795                           NaN
# 43221                           NaN
# 43329                           NaN
# 43374                           NaN
# 43893                           NaN
# 44055                           NaN
# 44196                           NaN
# 44296                           NaN
# 44347                           NaN
# 44348                           NaN
# 44377                           NaN
# 44674                           NaN
# 44701                           NaN
# 44771                           NaN
# 45195                           NaN
# 45351                           NaN
# 45633                           NaN
# 45842                           NaN
# 46222                           NaN
# 46340                           NaN
# 46579                           NaN
# 46691                           NaN
# 46977                           NaN
# 47158                           NaN
# 47193                           NaN
# 47203                           NaN
# 47381                           NaN
# 47405                           NaN
# 47596                           NaN
# 47727                           NaN
# 47802                           NaN
# 48524                           NaN
# 48680                           NaN
# 49484                           NaN
# 49612                           NaN
# 49832                           NaN
# 49947                           NaN
# 49948                           NaN
# 50318                           NaN
# 50739                           NaN
# 50749                           NaN
# 50863                           NaN
# 51330                           NaN
# 51544                           NaN
# 51547                           NaN
# 51652                           NaN
# 51683                           NaN
# 51819                           NaN
# 51847                           NaN
# 51893                           NaN
# 51910                           NaN
# 51922                           NaN
# 52014                           NaN
# 52127                           NaN
# 52140                           NaN
# 52573                           NaN
# 52655                           NaN
# 52908                           NaN
# 53005                           NaN
# 53066                           NaN
# 53162                           NaN
# 53164                           NaN
# 53280                           NaN
# 53374                           NaN
# 53567                           NaN
# 53637                           NaN
# 53836                           NaN
# 53861                           NaN
# 53950                           NaN
# 53980                           NaN
# 53993                           NaN
# 53994                           NaN
# 53996                           NaN
# 54262                           NaN
# 54580                           NaN
# 55075                           NaN
# 55283                           NaN
# 55480                           NaN
# 55556                           NaN
# 55605                           NaN
# 55754                           NaN
# 55760                           NaN
# 57055                           NaN
# 57129                           NaN
# 57172                           NaN
# 57363                           NaN
# 57526                           NaN
# 57696                           NaN
# 58172                           NaN
# 58195                           NaN
# 58505                           NaN
# 58724                           NaN
# 59061                           NaN
# 59993                           NaN
# 60022                           NaN
# 60357                           NaN
# 60440                           NaN
# 60448                           NaN
# 60469                           NaN
# 60723                           NaN
# 60984                           NaN
# 61331                           NaN
#
# [334 rows x 49 columns]
# Number of rows with PostalCode longer than 5 digits: 334
# Number of rows with PostalCode longer than 5 digits: 0

# %% [markdown]
# Cleaned zipcodes dropping invalid 5 digit zipcodes of 334 properties (Dropped total 339 properties.)
#
# ### 2) Longitude & Latitude
# Now we can use the zipcodes aligned with missing longitude and latitude if it exists still.

# %%
# check the missing values of longitude and latitude corresponding to zipcode
missing_longlat= df[(df['Latitude'].isna())|(df['Longitude'].isna())]

missing_longlat[["PostalCode", "City", "Latitude", "Longitude"]]
# Out:
#       PostalCode     City  Latitude  Longitude
# 17918      93923   Carmel       NaN        NaN
# 25894      95337  Manteca       NaN        NaN
# 32035      95337  Manteca       NaN        NaN
# 44034      95337  Manteca       NaN        NaN

# %% [markdown]
# We can see that longitude and latitude missing values are involved with same zipcodes. Let's fill missing values using zipcodes.

# %%
geolocator = Nominatim(user_agent="monument")

geocoder = RateLimiter(geolocator.geocode, min_delay_seconds=1)

#call all zipcodes that have missing values of longitude and latitude
zipcodes_missing = df.loc[df['Latitude'].isna(), 'PostalCode'].unique()

lat={}
lon={}

for i in zipcodes_missing:
  location = geocoder(i)
  lat[i] = location.latitude
  lon[i] = location.longitude

# fill missing values what we found longitude and latitude
df['Latitude'] = df['Latitude'].fillna(df['PostalCode'].map(lat))
df['Longitude'] = df['Longitude'].fillna(df['PostalCode'].map(lon))

#check if the missing values have filled
print("latitude misssing values:", df['Latitude'].isna().sum())
print("longitude misssing values:", df['Longitude'].isna().sum())

#checking what is filled on missing values of longitude and latitude
missing_check=df.loc[missing_longlat.index, ["PostalCode", "City", "Latitude", "Longitude"]]

missing_check
# Out:
# latitude misssing values: 0
# longitude misssing values: 0
#       PostalCode     City   Latitude   Longitude
# 17918      93923   Carmel  36.565661 -120.041916
# 25894      95337  Manteca  37.799693 -121.249470
# 32035      95337  Manteca  37.799693 -121.249470
# 44034      95337  Manteca  37.799693 -121.249470

# %% [markdown]
# We filled missing values using geocoding finding the latitude and longitude corresponding to their zipcodes. We did not drop the rows here.

# %% [markdown]
# Let's check if there is invalid location that approximately we use latitude of 32.53 ~ 42.01 and longitude of -124.41 ~ -114.13 across California.

# %%
#check the isolated area of California
plt.figure(figsize=(10, 10))
plt.scatter(df['Longitude'], df['Latitude'])
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Scatter Plot of Longitude vs Latitude')
plt.show()

# %% [markdown]
# There are some location were out of range, we will drop those properties.

# %%
#Drop the isloated area of California
df = df[(df['Latitude']>30)&(df['Longitude']<-50)]
row_df4 = df.shape[0]
print(row_df3-row_df4)

plt.figure(figsize=(10, 10))
plt.scatter(df['Longitude'], df['Latitude'])
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Scatter Plot of Longitude vs Latitude')
plt.show()
# Out:
# 344

# %% [markdown]
# We dropped 344 properties that were out of range location in terms of longitude and latittude.

# %% [markdown]
# ### 3) City & County

# %% [markdown]
# Let's check the missing values of cities and find those using geocoding instead of dropping to preserve representation of data.

# %%
#Find zipcodes that cities are missing.
missing_cities=df[df['City'].isna()]

missing_cities[["PostalCode", "City"]]
# Out:
#       PostalCode City
# 52         95672  NaN
# 196        92314  NaN
# 960        95002  NaN
# 1580       94065  NaN
# 1681       94933  NaN
# 5203       93933  NaN
# 6547       93933  NaN
# 7147       92679  NaN
# 7416       95628  NaN
# 7777       92277  NaN
# 9242       95076  NaN
# 9606       95076  NaN
# 10543      95004  NaN
# 11184      95385  NaN
# 12409      95004  NaN
# 13081      94065  NaN
# 14585      94550  NaN
# 15602      95004  NaN
# 15711      95004  NaN
# 16531      95004  NaN
# 17057      92277  NaN
# 18457      93908  NaN
# 18560      93933  NaN
# 18709      95567  NaN
# 19340      95002  NaN
# 19717      94920  NaN
# 21021      94065  NaN
# 21781      93908  NaN
# 23717      95004  NaN
# 26259      92240  NaN
# 26842      95004  NaN
# 27175      93608  NaN
# 27494      95004  NaN
# 31328      92314  NaN
# 31970      94516  NaN
# 33352      93668  NaN
# 35253      93267  NaN
# 36085      92277  NaN
# 37151      92308  NaN
# 38046      95364  NaN
# 38499      94303  NaN
# 41355      94065  NaN
# 43311      93933  NaN
# 45713      95004  NaN
# 46246      94028  NaN
# 46495      95002  NaN
# 46576      93266  NaN
# 46906      93668  NaN
# 52735      92028  NaN
# 53732      92116  NaN
# 53754      93668  NaN
# 53951      92314  NaN
# 55820      92567  NaN
# 57883      95076  NaN
# 60411      92037  NaN
# 61352      92277  NaN

# %%
#List all the zipcodes that are missing cities
zipcodes_missing_city = df.loc[df['City'].isna(), 'PostalCode'].unique()

#fill all the missing cities into missing values
city={}

for i in zipcodes_missing_city:
  city[i] = location.address.split(',')[1]

df['City'] = df['City'].fillna(df['PostalCode'].map(city))

#check if it filled
print("City missing values:", df['City'].isna().sum())


#Check what missing values have filled of missing cities

missing_check_cities=df.loc[missing_cities.index, ["PostalCode", "City"]]

missing_check_cities
# Out:
# City missing values: 0
#       PostalCode      City
# 52         95672   Manteca
# 196        92314   Manteca
# 960        95002   Manteca
# 1580       94065   Manteca
# 1681       94933   Manteca
# 5203       93933   Manteca
# 6547       93933   Manteca
# 7147       92679   Manteca
# 7416       95628   Manteca
# 7777       92277   Manteca
# 9242       95076   Manteca
# 9606       95076   Manteca
# 10543      95004   Manteca
# 11184      95385   Manteca
# 12409      95004   Manteca
# 13081      94065   Manteca
# 14585      94550   Manteca
# 15602      95004   Manteca
# 15711      95004   Manteca
# 16531      95004   Manteca
# 17057      92277   Manteca
# 18457      93908   Manteca
# 18560      93933   Manteca
# 18709      95567   Manteca
# 19340      95002   Manteca
# 19717      94920   Manteca
# 21021      94065   Manteca
# 21781      93908   Manteca
# 23717      95004   Manteca
# 26259      92240   Manteca
# 26842      95004   Manteca
# 27175      93608   Manteca
# 27494      95004   Manteca
# 31328      92314   Manteca
# 31970      94516   Manteca
# 33352      93668   Manteca
# 35253      93267   Manteca
# 36085      92277   Manteca
# 37151      92308   Manteca
# 38046      95364   Manteca
# 38499      94303   Manteca
# 41355      94065   Manteca
# 43311      93933   Manteca
# 45713      95004   Manteca
# 46246      94028   Manteca
# 46495      95002   Manteca
# 46576      93266   Manteca
# 46906      93668   Manteca
# 52735      92028   Manteca
# 53732      92116   Manteca
# 53754      93668   Manteca
# 53951      92314   Manteca
# 55820      92567   Manteca
# 57883      95076   Manteca
# 60411      92037   Manteca
# 61352      92277   Manteca

# %% [markdown]
# Most of the missing cities are from Manteca in California.
#
# Now if we check explicit missing values again.

# %%
location = ['Latitude', 'Longitude','CountyOrParish', 'City', 'StateOrProvince', 'PostalCode']
print(df[location].isna().sum())
# Out:
# Latitude           0
# Longitude          0
# CountyOrParish     0
# City               0
# StateOrProvince    0
# PostalCode         0
# dtype: int64

# %% [markdown]
# Now, let's check the cities and county values that there are so many distinct values influencing downside of predicting housing price.

# %%
city_count = df["City"].value_counts()
city_count
# Out:
# City
# Los Angeles                                    2515
# San Diego                                      2129
# San Jose                                       1131
# Riverside                                       942
# Oakland                                         757
# Menifee                                         694
# Lancaster                                       609
# Corona                                          588
# Long Beach                                      577
# Victorville                                     572
# Hemet                                           571
# Murrieta                                        565
# San Bernardino                                  544
# Moreno Valley                                   537
# La Quinta                                       529
# Oceanside                                       494
# Temecula                                        492
# Palmdale                                        492
# Fontana                                         467
# Apple Valley                                    460
# Palm Desert                                     445
# Escondido                                       445
# Indio                                           437
# Huntington Beach                                433
# Hesperia                                        392
# Rancho Cucamonga                                379
# Simi Valley                                     372
# Lake Elsinore                                   363
# Ontario                                         357
# Mission Viejo                                   357
# Irvine                                          348
# Whittier                                        348
# Beaumont                                        340
# Bakersfield                                     335
# Palm Springs                                    332
# Chico                                           332
# Chula Vista                                     331
# Carlsbad                                        326
# El Cajon                                        313
# Anaheim                                         304
# Merced                                          295
# Concord                                         288
# Livermore                                       286
# Antioch                                         286
# Winchester                                      278
# Pasadena                                        277
# Fullerton                                       272
# Perris                                          272
# Fremont                                         269
# Orange                                          267
# Torrance                                        266
# Valencia                                        266
# Rancho Mirage                                   264
# Vista                                           260
# Camarillo                                       255
# Redlands                                        249
# San Clemente                                    247
# Ventura                                         240
# Woodland Hills                                  239
# Jurupa Valley                                   234
# Brentwood                                       233
# Fallbrook                                       232
# Santa Ana                                       230
# Oxnard                                          229
# Chino Hills                                     227
# Thousand Oaks                                   227
# Salinas                                         226
# Upland                                          222
# Desert Hot Springs                              216
# Banning                                         216
# San Jacinto                                     213
# Cathedral City                                  211
# Hayward                                         211
# Yorba Linda                                     211
# San Marcos                                      203
# Rialto                                          201
# Costa Mesa                                      201
# Newport Beach                                   200
# Berkeley                                        199
# Sherman Oaks                                    199
# Garden Grove                                    198
# Santa Maria                                     196
# Pomona                                          196
# Yucca Valley                                    195
# Lakewood                                        193
# Danville                                        192
# La Mesa                                         189
# Pleasanton                                      188
# Yucaipa                                         187
# Paso Robles                                     186
# Burbank                                         185
# Lake Forest                                     185
# Chino                                           183
# Canyon Country                                  181
# Glendale                                        179
# Compton                                         178
# West Covina                                     178
# Richmond                                        177
# West Hills                                      175
# Highland                                        174
# Saugus                                          171
# Spring Valley                                   165
# Laguna Niguel                                   164
# Carson                                          162
# Eastvale                                        158
# Buena Park                                      156
# Encino                                          156
# La Puente                                       153
# Norwalk                                         153
# San Luis Obispo                                 152
# Covina                                          152
# Rancho Palos Verdes                             149
# Fresno                                          149
# Santa Cruz                                      147
# Oroville                                        147
# Ramona                                          146
# North Hollywood                                 144
# Dana Point                                      143
# Walnut Creek                                    142
# Glendora                                        142
# San Leandro                                     142
# Paicines                                          1
# Laytonville                                       1
# Foresthill                                        1
# Loma Mar                                          1
# Calipatria                                        1
# Wofford Heights                                   1
# Paradise Hills                                    1
# Summerland                                        1
# Benton                                            1
# Glenhaven                                         1
# Catheys Valley                                    1
# Unincorporated                                    1
# Dixon                                             1
# Amador City                                       1
# Sutter                                            1
# Oak Glen                                          1
# Loma Rica                                         1
# Raymond                                           1
# Pala                                              1
# San Geronimo                                      1
# Tres Pinos                                        1
# Rio Linda                                         1
# Davenport                                         1
# Gualala                                           1
# O'Neals                                           1
# Murphys                                           1
# Loch Lomond                                       1
# Sage                                              1
# Val Verde                                         1
# Woodlake                                          1
# Logan Heights                                     1
# Sonoma                                            1
# Cloverdale                                        1
# Los Alamos                                        1
# Glen Ellen                                        1
# East San Diego                                    1
# Buellton                                          1
# Hamilton City                                     1
# Artois                                            1
# Vina                                              1
# Mammoth Lakes                                     1
# Inverness                                         1
# Cowan Heights                                     1
# Smartsville                                       1
# Lytle Creek                                       1
# California Valley                                 1
# Lincoln Heights                                   1
# Scripps Miramar                                   1
# Manton                                            1
# Prather                                           1
# Sausalito                                         1
# Chester                                           1
# Stonyford                                         1
# Rainbow                                           1
# Outside Area (Outside U.S.) Foreign Country       1
# Highland Park                                     1
# Isleton                                           1
# Rohnert Park                                      1
# Dinuba                                            1
# Bodfish                                           1
# Woodcrest                                         1
# Fish Camp                                         1
# Angels Camp                                       1
# Mountain Home Village                             1
# Weed                                              1
# Midpines                                          1
# Oregon House                                      1
# Manchester                                        1
# Riverdale                                         1
# Otay Mesa                                         1
# Anderson                                          1
# Valyermo                                          1
# Exeter                                            1
# Cazadero                                          1
# French Camp                                       1
# Name: count, dtype: int64

# %%
county_count = df["CountyOrParish"].value_counts()
county_count
# Out:
# CountyOrParish
# Los Angeles        15226
# Riverside           9789
# San Diego           6762
# San Bernardino      6639
# Orange              5887
# Alameda             2707
# Contra Costa        2593
# Santa Clara         2152
# Ventura             1918
# San Luis Obispo      959
# San Mateo            953
# Monterey             688
# Kern                 680
# Butte                661
# Merced               501
# Santa Cruz           433
# Santa Barbara        335
# San Joaquin          323
# Solano               289
# Lake                 283
# Fresno               260
# Madera               240
# Sacramento           185
# San Benito           148
# Stanislaus           126
# San Francisco        111
# Mendocino             74
# Glenn                 72
# Tehama                69
# Tulare                61
# Mariposa              52
# Imperial              50
# Kings                 39
# Yuba                  32
# Placer                30
# Sonoma                28
# Marin                 23
# Sutter                21
# Napa                  21
# Shasta                20
# Calaveras             17
# Tuolumne              16
# El Dorado             13
# Yolo                  10
# Trinity                6
# Plumas                 6
# Siskiyou               5
# Nevada                 4
# Colusa                 4
# Amador                 4
# Mono                   2
# Humboldt               1
# Del Norte              1
# Inyo                   1
# Foreign Country        1
# Other State            1
# Name: count, dtype: int64

# %% [markdown]
# There are many unique values in the cities that will cause issue while direct one-hot encoding, which will create hundreds of sparse variables and increase the risk of overfitting.
#
# Let's check the county

# %%
county_count = df["CountyOrParish"].value_counts()
county_count
# Out:
# CountyOrParish
# Los Angeles        15226
# Riverside           9789
# San Diego           6762
# San Bernardino      6639
# Orange              5887
# Alameda             2707
# Contra Costa        2593
# Santa Clara         2152
# Ventura             1918
# San Luis Obispo      959
# San Mateo            953
# Monterey             688
# Kern                 680
# Butte                661
# Merced               501
# Santa Cruz           433
# Santa Barbara        335
# San Joaquin          323
# Solano               289
# Lake                 283
# Fresno               260
# Madera               240
# Sacramento           185
# San Benito           148
# Stanislaus           126
# San Francisco        111
# Mendocino             74
# Glenn                 72
# Tehama                69
# Tulare                61
# Mariposa              52
# Imperial              50
# Kings                 39
# Yuba                  32
# Placer                30
# Sonoma                28
# Marin                 23
# Sutter                21
# Napa                  21
# Shasta                20
# Calaveras             17
# Tuolumne              16
# El Dorado             13
# Yolo                  10
# Trinity                6
# Plumas                 6
# Siskiyou               5
# Nevada                 4
# Colusa                 4
# Amador                 4
# Mono                   2
# Humboldt               1
# Del Norte              1
# Inyo                   1
# Foreign Country        1
# Other State            1
# Name: count, dtype: int64

# %%
print(county_count.loc["San Francisco"])
# Out:
# 111

# %%
print((df["CountyOrParish"] == "San Francisco").sum())
# Out:
# 111

# %% [markdown]
# There are many counties that are less than 100 properties in California, however, there are less unique numbers of counties compare to city.
#
# We will try to group the properties that are less than 100 houses in each county into "Others".

# %%
county_count = df["CountyOrParish"].value_counts()

other_counties_index = county_count[
    county_count <= 100
].index

other_counties_index
# Out:
# Index(['Mendocino', 'Glenn', 'Tehama', 'Tulare', 'Mariposa', 'Imperial',
#        'Kings', 'Yuba', 'Placer', 'Sonoma', 'Marin', 'Sutter', 'Napa',
#        'Shasta', 'Calaveras', 'Tuolumne', 'El Dorado', 'Yolo', 'Trinity',
#        'Plumas', 'Siskiyou', 'Nevada', 'Colusa', 'Amador', 'Mono', 'Humboldt',
#        'Del Norte', 'Inyo', 'Foreign Country', 'Other State'],
#       dtype='object', name='CountyOrParish')

# %% [markdown]
# These are the list of counties that are combined into **"Others"** value.

# %%
county_count[county_count<=100].sum() / df.shape[0]
# Out:
# np.float64(0.011116167197555744)

# %% [markdown]
# The proportion is good that it is not dominated across the counties. We will use this and apply to the original dataset of **CountyOrParish** feature.

# %%
df["CountyOrParish"] = df["CountyOrParish"].replace(
    other_counties_index,
    "Others"
)

df["CountyOrParish"].value_counts()
# Out:
# CountyOrParish
# Los Angeles        15226
# Riverside           9789
# San Diego           6762
# San Bernardino      6639
# Orange              5887
# Alameda             2707
# Contra Costa        2593
# Santa Clara         2152
# Ventura             1918
# San Luis Obispo      959
# San Mateo            953
# Monterey             688
# Others               684
# Kern                 680
# Butte                661
# Merced               501
# Santa Cruz           433
# Santa Barbara        335
# San Joaquin          323
# Solano               289
# Lake                 283
# Fresno               260
# Madera               240
# Sacramento           185
# San Benito           148
# Stanislaus           126
# San Francisco        111
# Name: count, dtype: int64

# %% [markdown]
# The City feature contains a large number of unique categories, including many cities with only a small number of observations. Using **City** directly could create a high-dimensional and sparse representation, which may increase model complexity and the risk of overfitting. Therefore, **CountyOrParish** was selected as primary location feature because it has fewer categories and provides more stable regional representation.

# %% [markdown]
# ## Retaining preprocessing

# %% [markdown]
# The preprocessing pipeline was developed collaboratively, with team members responsible for different categories of variables. External macroeconomic data, including unemployment, CPI, the federal funds rate, and the 30-year mortgage rate, were matched to each transaction using the property’s closing month. California sales-tax rates were assigned using the original city name when available, followed by the county rate and the statewide base rate as fallbacks.

# %%
output_dir = './output'
os.makedirs(output_dir, exist_ok=True)

# Macro Features - Tara
# including: Unemployment Rate, Inflation Rate, Interest Rate, CA Sales tax, Mortgage Rate 30 fixed
data_unemploy = pd.read_csv("/content/UNRATE (2).csv")
data_cpi = pd.read_csv("/content/CPIAUCNS (2).csv")
data_mortgage30us = pd.read_csv("/content/MORTGAGE30US (2).csv")
data_fedfunds = pd.read_csv("/content/FEDFUNDS (2).csv")
data_salestax = pd.read_csv("/content/SalesTaxRates (2).csv")

# CA Sales Tax
city_rate_map = data_salestax[data_salestax['Type'] == 'City'].set_index('Location')['Rate'].to_dict()
county_rate_map = data_salestax[data_salestax['Type'] == 'County'].set_index('County')['Rate'].to_dict()

def get_sales_tax_rate(row):
    city = row['City']
    county = row['CountyOrParish']
    # city match first
    if city in city_rate_map:
        return city_rate_map[city]
    # then county match
    elif county in county_rate_map:
        return county_rate_map[county]
    else:
        return 0.0725  # CA statewide tax rate
df['SalesTaxRate'] = df.apply(get_sales_tax_rate, axis=1)

df['CloseDate_Parsed'] = pd.to_datetime(df['CloseDate'], errors='coerce')
df['CloseDate_YearMonth'] = df['CloseDate_Parsed'].dt.strftime('%Y-%m')

# FedInterestRate
data_fedfunds['observation_date'] = pd.to_datetime(data_fedfunds['observation_date'])
data_fedfunds['CloseDate_YearMonth'] = data_fedfunds['observation_date'].dt.strftime('%Y-%m')
data_fedfunds = data_fedfunds.rename(columns={'FEDFUNDS': 'FedInterestRate'})

# Unemployment
data_unemploy['observation_date'] = pd.to_datetime(data_unemploy['observation_date'])
data_unemploy['CloseDate_YearMonth'] = data_unemploy['observation_date'].dt.strftime('%Y-%m')
data_unemploy = data_unemploy.rename(columns={'UNRATE': 'UnemploymentRate'})

# CPI
data_cpi['observation_date'] = pd.to_datetime(data_cpi['observation_date'])
data_cpi['CloseDate_YearMonth'] = data_cpi['observation_date'].dt.strftime('%Y-%m')
data_cpi = data_cpi.rename(columns={'CPIAUCNS': 'CPI'})

# Mortgage rate
data_mortgage30us['observation_date'] = pd.to_datetime(data_mortgage30us['observation_date'])
data_mortgage30us['CloseDate_YearMonth'] = data_mortgage30us['observation_date'].dt.strftime('%Y-%m')
data_mortgage30us = data_mortgage30us.rename(columns={'MORTGAGE30US': 'MortgageRate30Fixed'})

# Merge all macro data on CloseDate_YearMonth
df = df.merge(data_unemploy[['CloseDate_YearMonth', 'UnemploymentRate']], on='CloseDate_YearMonth', how='left')
df = df.merge(data_mortgage30us[['CloseDate_YearMonth', 'MortgageRate30Fixed']], on='CloseDate_YearMonth', how='left')
df = df.merge(data_fedfunds[['CloseDate_YearMonth', 'FedInterestRate']], on='CloseDate_YearMonth', how='left')
df = df.merge(data_cpi[['CloseDate_YearMonth', 'CPI']], on='CloseDate_YearMonth', how='left')
print(df[['CloseDate_YearMonth', 'UnemploymentRate', 'MortgageRate30Fixed', 'FedInterestRate', 'CPI']].drop_duplicates().sort_values('CloseDate_YearMonth'))

# Fill missing macro values with the median
macro_cols = ['UnemploymentRate', 'MortgageRate30Fixed', 'FedInterestRate', 'CPI']
for col in macro_cols:
    median_val = df[col].median()
    df[col] = df[col].fillna(median_val)

# Remove outliers from ClosePrice
lower = df['ClosePrice'].quantile(0.01)
upper = df['ClosePrice'].quantile(0.99)
df = df[(df['ClosePrice'] >= lower) & (df['ClosePrice'] <= upper)]

# Remove outliers from property features - Tara
property_features = [
    'LivingArea', 'BathroomsTotalInteger','BedroomsTotal', 'Stories',
    'GarageSpaces', 'LotSizeSquareFeet'
]

for col in property_features:
    lower = df[col].quantile(0.01)
    upper = df[col].quantile(0.99)
    df = df[(df[col] >= lower) & (df[col] <= upper)]

# Calculate House Age - Tommy
current_year = datetime.now().year
df['Age'] = current_year - df['YearBuilt']

# Feature Engineering lot density
df['LotDensity'] = df['LotSizeSquareFeet'] / df['LivingArea']
df['LotDensity'].replace([np.inf, -np.inf], np.nan, inplace=True)

# Impute missing values (Median imputation for missing values, since the data is right-skewed) - Tara
df['LivingArea'] = df['LivingArea'].fillna(df['LivingArea'].median())
df['Stories'] = df['Stories'].fillna(df['Stories'].median())
df['GarageSpaces'] = df['GarageSpaces'].fillna(df['GarageSpaces'].median())
df['LotSizeSquareFeet'] = df['LotSizeSquareFeet'].fillna(df['LotSizeSquareFeet'].median())
df['LotDensity'].fillna(df['LotDensity'].median(), inplace=True)

# Handle boolean facilities - Abhishek
facilities_features_bool = [
    'ViewYN','PoolPrivateYN', 'AttachedGarageYN',
    'ParkingTotal', 'FireplaceYN', 'NewConstructionYN'
]
# Hazel Note: filled with 0 instead of -1 as per discussed in the meeting
df[facilities_features_bool] = df[facilities_features_bool].fillna(0).astype(int)

# Flooring: one-hot encode multi-label values
df['Flooring'] = df['Flooring'].fillna('Unknown')
df['Flooring'] = df['Flooring'].str.split(',')
mlb = MultiLabelBinarizer()
flooring_dummies = pd.DataFrame(
    mlb.fit_transform(df['Flooring']),
    columns=['Flooring_' + f for f in mlb.classes_],
    index=df.index
)
df = pd.concat([df, flooring_dummies], axis=1)
df.drop(columns='Flooring', inplace=True)

# Create GeoDataFrame from coordinates - Hazel
geometry = [Point(xy) for xy in zip(df['Longitude'], df['Latitude'])]
homes_gdf = gpd.GeoDataFrame(df, geometry=geometry, crs="EPSG:4326")

# Load school districts shapefile (shp file needs shx and dbf files in the same directory)
districts_gdf = gpd.read_file('/content/tl_2023_06_unsd.shp')

# If the shapefile reports no CRS, assign the known native CRS (set, not transform)
if districts_gdf.crs is None:
    districts_gdf = districts_gdf.set_crs("EPSG:4269")  # TIGER/Line default

# Now you can safely transform to match your points (EPSG:4326)
districts_gdf = districts_gdf.to_crs(homes_gdf.crs)

# (Optional) heal invalid polygons before the join
districts_gdf['geometry'] = districts_gdf.buffer(0)

# Join and clean columns
homes_with_district = gpd.sjoin(homes_gdf, districts_gdf, how='left', predicate='within')

district_name_col = 'NAME'
district_id_col = 'GEOID'

extra_cols = set(homes_with_district.columns) - set(homes_gdf.columns) - {'index_right'}
to_drop = extra_cols - {district_name_col, district_id_col}
homes_with_district = homes_with_district.drop(columns=to_drop)

# Rename for clarity
homes_with_district = homes_with_district.rename(columns={
    district_name_col: 'SchoolDistrictName',
    district_id_col: 'SchoolDistrictID'
})

# One-hot encode school district name
homes_with_district['SchoolDistrictName'] = homes_with_district['SchoolDistrictName'].fillna('Unknown')
district_dummies = pd.get_dummies(homes_with_district['SchoolDistrictName'], prefix='District_')
df = pd.concat([homes_with_district.drop(columns=['SchoolDistrictName']), district_dummies], axis=1)

# Drop temporary columns created during processing
df = df.drop(columns=[
    'StreetNumberNumeric', 'YearBuilt', 'CloseDate', 'CloseDate_Parsed', 'CloseDate_YearMonth',
    'index_right', 'SchoolDistrictID', 'UnparsedAddress', 'StateOrProvince',
     'geometry',
    ])

# # Save to CSV
import google.colab.files as files

df.to_csv("cleaned_data_.csv", index=False)
files.download("cleaned_data_.csv")
# Out:
#       CloseDate_YearMonth  UnemploymentRate  MortgageRate30Fixed  \
# 0                 2024-12               4.1                 6.72
# 10557             2025-01               4.0                 6.96
# 18665             2025-02               4.1                 6.84
# 27471             2025-03               4.2                 6.65
# 38019             2025-04               4.2                 6.73
# 49821             2025-05               4.2                 6.82
#
#        FedInterestRate      CPI
# 0                 4.48  315.605
# 10557             4.33  317.671
# 18665             4.33  319.082
# 27471             4.33  319.799
# 38019             4.33  320.795
# 49821             4.33  321.465
# /tmp/ipykernel_2939/3189283663.py:87: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['LotDensity'].replace([np.inf, -np.inf], np.nan, inplace=True)
# /tmp/ipykernel_2939/3189283663.py:94: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['LotDensity'].fillna(df['LotDensity'].median(), inplace=True)

# %% [markdown]
# Extreme observations were filtered using the 1st and 99th percentiles of ClosePrice and selected property characteristics. Missing values in right-skewed numeric features, including living area, garage spaces, stories, lot size, and the lot-to-living-area ratio, were filled using the median. Property age and lot density were engineered to provide more interpretable structural features.
#
# Boolean housing amenities were converted into numeric indicators, while flooring was treated as a multi-label categorical variable. Missing flooring information was retained as an Unknown category rather than predicted because the missingness was substantial and reliable classification could not be guaranteed. The flooring values were then converted into separate binary columns using multi-label encoding.
#
# Geographic preprocessing used property latitude and longitude to create spatial points. These points were joined with school-district boundary polygons so that each property could be assigned to a district based on its geographic location. This approach reduced reliance on the original school-district field, which contained substantial missingness. School-district names were subsequently converted into dummy variables for modeling.
#
# The City variable was retained during preprocessing because it was required for external data matching, such as sales-tax assignment. However, it was not prioritized as a direct model feature because it contained many unique and rare categories, which could create a sparse high-dimensional representation and increase the risk of overfitting. County, latitude, longitude, ZIP code, school district, and geographic cluster features were used to provide broader and more stable location information.
